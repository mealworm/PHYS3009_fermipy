# %% [markdown]
# # Likelihood Analysis with fermipy

# %% [markdown]
# The python likelihood tools are a very powerful set of analysis tools that expand upon the command line tools provided with the Fermi Science Tools package. Not only can you perform all of the same likelihood analysis with the python tools that you can with the standard command line tools but you can directly access all of the model parameters. You can more easily script a standard analysis. There are also a few things built into the python tools that are not available from the command line like the calculation of upper limits.
#
# There are many user contributed packages built upon the python backbone of the Science Tools and this thread will highlight the use of the [fermipy](http://fermipy.readthedocs.org) package.
#
# This sample analysis of PKS 2155-304 is based on the PG 1553+113 analysis performed by the LAT team and described in [Abdo, A. A. et al. 2010, ApJ, 708, 1310](http://adsabs.harvard.edu/abs/2010ApJ...708.1310A) and closely follows the [Likelihood Analysis with Python](http://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/python_tutorial.html) thread.  This tutorial assumes you have the most recent ScienceTools installed and [fermipy](http://fermipy.readthedocs.org) installed on top of it.  For instructions on installing fermipy and the Fermi ScienceTools you should consult the [fermipy Installation Instructions](http://fermipy.readthedocs.org/en/latest/install.html).  We will also make significant use of python, so you might want to familiarize yourself with python including matplotlib and other libraries (there's a beginner's guide at http://wiki.python.org/moin/BeginnersGuide). This tutorial also assumes that you've gone through the non-python based [Unbinned Likelihood Tutorial](http://fermi.gsfc.nasa.gov/ssc/data/analysis/scitools/likelihood_tutorial.html).

# %% [markdown]
# ## Get the Data

# %% [markdown]
# For this thread the original data were extracted from the [LAT data server](http://fermi.gsfc.nasa.gov/cgi-bin/ssc/LAT/LATDataQuery.cgi) with the following selections (these selections are similar to those in the paper):
#
# * Search Center (RA,Dec) = (329.717,-30.2256)
# * Radius = 15 degrees
# * Start Time (MET) = 241401601 seconds (2008-08-26T00:00:00)
# * Stop Time (MET) = 257385601 seconds (2009-02-26T23:59:59)
# * Minimum Energy = 100 MeV
# * Maximum Energy = 300000 MeV
#
# The data are already in the repository in the *data* directory.  In this example the output of the analysis will go into a subdirectory called *pks2155*.

# %%
import os

if os.path.isdir('data'):
    os.environ['DATADIR'] = 'data'

if os.path.isfile('diffuse.tar.gz'):
    # !tar xzf diffuse.tar.gz
else:
    # !curl -OL https://raw.githubusercontent.com/fermiPy/fermipy-extras/master/data/diffuse.tar.gz
    # !tar xzf diffuse.tar.gz

# %% [markdown]
# ### Make a file list
#
# You'll then need to make a file list with the names of your input event files. You can either just make one with a text editor or do the following from the command line.

# %%
# !ls -1 data/*PH*.fits > data/PKS2155.lst

# %% [markdown]
# ## Make a config file
#
# fermipy bases its analysis on a configuration file (in [yaml](http://yaml.org) format).  We're just going to use a really simple config file for a standard analysis.  There are many many more options which you can use or you can modify these options after the fact within the analysis chain.
#
#
# Make a config file named 'config.yaml' like the following.  For more details on the config file see [config.html](http://fermipy.readthedocs.org/en/latest/config.html).  You will probably need to customize this a bit since your files might not be in the same place or named the same.  The galactic and isotropic diffuse will need to be located on your system (they are included in the science tools or can be downloaded from the FSSC).  In the following example we set the path to these files with the environment variable FERMI_DIFFUSE_DIR.  If FERMI_DIFFUSE_DIR is not defined fermipy will look for the location of these files within the FSSC STs distribution.
#
# ```
# data:
#   evfile : PKS2155.lst
#   scfile : data/L211025154921445A2D9929_SC00.fits
#
# binning:
#   roiwidth   : 10.0
#   binsz      : 0.1
#   binsperdec : 8
#
# selection :
#   emin : 100
#   emax : 300000
#   tmin : 241401601
#   tmax : 257385601
#   zmax    : 90
#   evclass : 128
#   evtype  : 3
#   target : 'PKS 2155-304'
#
# gtlike:
#   edisp : True
#   irfs : 'P8R2_SOURCE_V6'
#   edisp_disable : ['isodiff','galdiff']
#
# model:
#   src_roiwidth : 15.0
#   galdiff  : 'diffuse/gll_iem_v07.fits'
#   isodiff  : 'diffuse/iso_P8R2_SOURCE_V6_v06.txt'
#   catalogs : ['4FGL']
# ```

# %% [markdown]
# ## Start the analysis
#
# Next, you create an analysis script and run the setup steps which include running the selections and generating exposure maps etc.  This will take a bit.
#
# This is where the magic happens.  fermipy will load the point source model, create your xml file for you, decide on all the appropriate cuts and binnings and just go.  All of this is configurable from python or from the config file.  And, if you need to rerun things, it's smart enough to not overwrite files if it doesn't need to.

# %% [markdown]
# ### Load up some useful modules

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import matplotlib
import numpy as np

# %% [markdown]
# ### Import the GTAnalysis module from fermipy
#
# You start by importing the module and then creating an instance of the analysis object from our config file.  When instantiating the analysis object we can override any options defined in the configuration file by passing keyword arguments to the object constructor.  Here we explicitly set the verbosity parameter to 3 (INFO) which supresses DEBUG output.  When we create the object, it spits out a bunch of information about all of the parameters that were used.  You can see there are many more options than the ones we chose.

# %%
from fermipy.gtanalysis import GTAnalysis
gta = GTAnalysis('data/config.yaml',logging={'verbosity': 3})
matplotlib.interactive(True)
# Out:
# 2021-10-31 16:48:53 INFO    GTAnalysis.__init__():
# --------------------------------------------------------------------------------
# fermipy version v1.0.1
# ScienceTools version 2.0.8

# %% [markdown]
# ### The setup routine
#
# This gets everything ready for the likelihood analysis including instantiating the pylikelihood object.  Note that fermipy will skip generating any ancillary files that already exist in the working directory.  In the sample tarball these files have already been produced in order to speed up this stage of the analysis.  If you want to see the behavior of fermipy when running from an empty working directory you can delete one or more of these files before running *setup*.

# %%
gta.setup()
# Out:
# 2021-10-31 16:48:56 INFO    GTAnalysis.setup(): Running setup.
# 2021-10-31 16:48:56 INFO    GTBinnedAnalysis.setup(): Running setup for component 00
# 2021-10-31 16:48:56 INFO    GTBinnedAnalysis.run_gtapp(): Running gtselect.
# 2021-10-31 16:48:56 INFO    GTBinnedAnalysis.run_gtapp(): time -p gtselect infile=/mnt/storage1/users/chen/PHYS3009_fermipy/data/evfile_00.txt outfile=/mnt/storage1/users/chen/PHYS3009_fermipy/data/ft1_00.fits ra=329.714111328125 dec=-30.225099563598633 rad=7.5710678118654755 tmin=241401601.0 tmax=257385601.0 emin=100.0 emax=300000.0 zmin=0.0 zmax=90.0 evclass=128 evtype=3 convtype=-1 phasemin=0.0 phasemax=1.0 evtable="EVENTS" chatter=3 clobber=yes debug=no gui=no mode="ql"
# 2021-10-31 16:48:56 INFO    GTBinnedAnalysis.run_gtapp(): This is gtselect version HEAD
# 2021-10-31 16:48:56 INFO    GTBinnedAnalysis.run_gtapp(): Applying filter string: ((EVENT_CLASS&o200) != o0) && angsep(RA,DEC,329.7141113,-30.22509956) < 7.571067812 && ((EVENT_TYPE&o3) != o0) && 100 < ENERGY && ENERGY <= 300000 && 241401601 < TIME && TIME <= 257385601 && 0 < ZENITH_ANGLE && ZENITH_ANGLE <= 90 && gtifilter()
# 2021-10-31 16:48:57 INFO    GTBinnedAnalysis.run_gtapp(): Done.
# 2021-10-31 16:48:57 INFO    GTBinnedAnalysis.run_gtapp(): Finished gtselect. Execution time: 0.83 s
# 2021-10-31 16:48:57 INFO    GTBinnedAnalysis.setup(): Using external LT cube.
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/fermipy/irfs.py:51: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   log_ratio = np.log(x[xs1] / x[xs0])
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/fermipy/irfs.py:52: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return 0.5 * (y[ys0] * x[xs0] + y[ys1] * x[xs1]) * log_ratio
# 2021-10-31 16:48:58 INFO    GTBinnedAnalysis.run_gtapp(): Running gtbin.
# 2021-10-31 16:48:58 INFO    GTBinnedAnalysis.run_gtapp(): time -p gtbin evfile=/mnt/storage1/users/chen/PHYS3009_fermipy/data/ft1_00.fits scfile=/mnt/storage1/users/chen/PHYS3009_fermipy/data/L211025154921445A2D9929_SC00.fits outfile=/mnt/storage1/users/chen/PHYS3009_fermipy/data/ccube_00.fits algorithm="ccube" ebinalg="LOG" emin=100.0 emax=300000.0 enumbins=14 ebinfile=NONE tbinalg="LIN" tbinfile=NONE nxpix=100 nypix=100 binsz=0.1 coordsys="CEL" xref=329.714111328125 yref=-30.225099563598633 axisrot=0.0 rafield="RA" decfield="DEC" proj="AIT" hpx_ordering_scheme="RING" hpx_order=3 hpx_ebin=yes hpx_region="" evtable="EVENTS" sctable="SC_DATA" efield="ENERGY" tfield="TIME" chatter=3 clobber=yes debug=no gui=no mode="ql"
# 2021-10-31 16:48:58 INFO    GTBinnedAnalysis.run_gtapp(): This is gtbin version HEAD
# 2021-10-31 16:48:59 INFO    GTBinnedAnalysis.run_gtapp(): Finished gtbin. Execution time: 0.74 s
# 2021-10-31 16:48:59 INFO    GTBinnedAnalysis.run_gtapp(): Running gtexpcube2.
# 2021-10-31 16:48:59 INFO    GTBinnedAnalysis.run_gtapp(): time -p gtexpcube2 infile=/mnt/storage1/users/chen/PHYS3009_fermipy/data/ltcube_00.fits cmap=none outfile=/mnt/storage1/users/chen/PHYS3009_fermipy/data/bexpmap_00.fits irfs="P8R2_SOURCE_V6" evtype=3 edisp_bins=-1 nxpix=360 nypix=180 binsz=1.0 coordsys="CEL" xref=0.0 yref=0.0 axisrot=0.0 proj="CAR" ebinalg="LOG" emin=100.0 emax=300000.0 enumbins=14 ebinfile="NONE" hpx_ordering_scheme="RING" hpx_order=6 bincalc="EDGE" ignorephi=no thmax=180.0 thmin=0.0 table="EXPOSURE" chatter=3 clobber=yes debug=no mode="ql"
# 2021-10-31 16:48:59 INFO    GTBinnedAnalysis.run_gtapp(): This is gtexpcube2 version HEAD
# 2021-10-31 16:48:59 INFO    GTBinnedAnalysis.run_gtapp(): Using evtype=3 (i.e., FRONT/BACK irfs)
# 2021-10-31 16:48:59 INFO    GTBinnedAnalysis.run_gtapp(): ResponseFunctions::load: IRF used: P8R2_SOURCE_V6
# 2021-10-31 16:48:59 INFO    GTBinnedAnalysis.run_gtapp(): event_types:  0  1
# 2021-10-31 16:49:05 INFO    GTBinnedAnalysis.run_gtapp(): Computing binned exposure map....................!
# 2021-10-31 16:49:06 INFO    GTBinnedAnalysis.run_gtapp(): Finished gtexpcube2. Execution time: 6.69 s
# 2021-10-31 16:49:06 INFO    GTBinnedAnalysis.run_gtapp(): Running gtexpcube2.
# 2021-10-31 16:49:06 INFO    GTBinnedAnalysis.run_gtapp(): time -p gtexpcube2 infile=/mnt/storage1/users/chen/PHYS3009_fermipy/data/ltcube_00.fits cmap=none outfile=/mnt/storage1/users/chen/PHYS3009_fermipy/data/bexpmap_roi_00.fits irfs="P8R2_SOURCE_V6" evtype=3 edisp_bins=0 nxpix=100 nypix=100 binsz=0.1 coordsys="CEL" xref=329.714111328125 yref=-30.225099563598633 axisrot=0.0 proj="CAR" ebinalg="LOG" emin=100.0 emax=300000.0 enumbins=14 ebinfile="NONE" hpx_ordering_scheme="RING" hpx_order=6 bincalc="EDGE" ignorephi=no thmax=180.0 thmin=0.0 table="EXPOSURE" chatter=3 clobber=yes debug=no mode="ql"
# 2021-10-31 16:49:06 INFO    GTBinnedAnalysis.run_gtapp(): This is gtexpcube2 version HEAD
# 2021-10-31 16:49:06 INFO    GTBinnedAnalysis.run_gtapp(): Using evtype=3 (i.e., FRONT/BACK irfs)
# 2021-10-31 16:49:06 INFO    GTBinnedAnalysis.run_gtapp(): ResponseFunctions::load: IRF used: P8R2_SOURCE_V6
# 2021-10-31 16:49:06 INFO    GTBinnedAnalysis.run_gtapp(): event_types:  0  1
# 2021-10-31 16:49:07 INFO    GTBinnedAnalysis.run_gtapp(): Computing binned exposure map....................!
# 2021-10-31 16:49:07 INFO    GTBinnedAnalysis.run_gtapp(): Finished gtexpcube2. Execution time: 1.49 s
# WARNING: FITSFixedWarning: RADECSYS= 'FK5 '
# the RADECSYS keyword is deprecated, use RADESYSa. [astropy.wcs.wcs]
# 2021-10-31 16:49:07 INFO    GTBinnedAnalysis.run_gtapp(): Running gtsrcmaps.
# 2021-10-31 16:49:07 INFO    GTBinnedAnalysis.run_gtapp(): time -p gtsrcmaps scfile=/mnt/storage1/users/chen/PHYS3009_fermipy/data/L211025154921445A2D9929_SC00.fits sctable="SC_DATA" expcube=/mnt/storage1/users/chen/PHYS3009_fermipy/data/ltcube_00.fits cmap=/mnt/storage1/users/chen/PHYS3009_fermipy/data/ccube_00.fits srcmdl=/mnt/storage1/users/chen/PHYS3009_fermipy/data/srcmdl_00.xml bexpmap=/mnt/storage1/users/chen/PHYS3009_fermipy/data/bexpmap_00.fits wmap=none outfile=/mnt/storage1/users/chen/PHYS3009_fermipy/data/srcmap_00.fits irfs="P8R2_SOURCE_V6" evtype=3 convol=yes resample=yes rfactor=2 minbinsz=0.05 ptsrc=yes psfcorr=yes emapbnds=no edisp_bins=-1 copyall=no chatter=3 clobber=yes debug=no gui=no mode="ql"
# 2021-10-31 16:49:07 INFO    GTBinnedAnalysis.run_gtapp(): This is gtsrcmaps version HEAD
# 2021-10-31 16:49:07 INFO    GTBinnedAnalysis.run_gtapp(): Using evtype=3 (i.e., FRONT/BACK irfs)
# 2021-10-31 16:49:07 INFO    GTBinnedAnalysis.run_gtapp(): ResponseFunctions::load: IRF used: P8R2_SOURCE_V6
# 2021-10-31 16:49:07 INFO    GTBinnedAnalysis.run_gtapp(): event_types:  0  1
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2158.8-3013
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2151.8-3027
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2159.1-2840
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2150.7-2810
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2145.0-3356
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2137.4-3209
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2142.5-2552
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2212.9-2526
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2200.7-2414
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2227.9-3031
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2131.0-2746
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2221.9-3504
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2123.8-3148
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2131.7-2515
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2141.8-3727
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2124.7-3358
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named 4FGL J2235.8-3627
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named isodiff
# 2021-10-31 16:49:16 INFO    GTBinnedAnalysis.run_gtapp(): Creating source named galdiff
# 2021-10-31 16:49:17 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2123.8-3148 15....................!
# 2021-10-31 16:49:18 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2124.7-3358 15....................!
# 2021-10-31 16:49:19 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2131.0-2746 15....................!
# 2021-10-31 16:49:20 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2131.7-2515 15....................!
# 2021-10-31 16:49:21 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2137.4-3209 15....................!
# 2021-10-31 16:49:22 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2141.8-3727 15....................!
# 2021-10-31 16:49:23 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2142.5-2552 15....................!
# 2021-10-31 16:49:24 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2145.0-3356 15....................!
# 2021-10-31 16:49:25 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2150.7-2810 15....................!
# 2021-10-31 16:49:26 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2151.8-3027 15....................!
# 2021-10-31 16:49:27 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2158.8-3013 15....................!
# 2021-10-31 16:49:28 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2159.1-2840 15....................!
# 2021-10-31 16:49:29 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2200.7-2414 15....................!
# 2021-10-31 16:49:30 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2212.9-2526 15....................!
# 2021-10-31 16:49:31 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2221.9-3504 15....................!
# 2021-10-31 16:49:32 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2227.9-3031 15....................!
# 2021-10-31 16:49:33 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for 4FGL J2235.8-3627 15....................!
# 2021-10-31 16:50:03 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for galdiff 15....................!
# 2021-10-31 16:50:30 INFO    GTBinnedAnalysis.run_gtapp(): Generating SourceMap for isodiff 15....................!
# 2021-10-31 16:50:31 INFO    GTBinnedAnalysis.run_gtapp(): Finished gtsrcmaps. Execution time: 83.70 s
# 2021-10-31 16:50:31 INFO    GTBinnedAnalysis.setup(): Finished setup for component 00
# 2021-10-31 16:50:31 INFO    GTBinnedAnalysis._create_binned_analysis(): Creating BinnedAnalysis for component 00.
# 2021-10-31 16:50:40 INFO    GTAnalysis.setup(): Initializing source properties
# 2021-10-31 16:50:40 INFO    GTAnalysis.setup(): Finished setup.

# %% [markdown]
# Before proceeding with the analysis we'll have a quick look at the files that are produced by the setup function.

# %%
ls data/*.fits
# Out:
# data/bexpmap_00.fits      data/L211025154921445A2D9929_PH00.fits
# data/bexpmap_roi_00.fits  data/L211025154921445A2D9929_PH01.fits
# data/ccube_00.fits        data/L211025154921445A2D9929_SC00.fits
# data/ccube.fits           data/ltcube_00.fits
# data/ft1_00.fits          data/srcmap_00.fits

# %% [markdown]
# Here is a brief explanation of the contents of each file and its role in the analysis:
#
# * **ft1_00.fits**: Event list.  This is generated by running gtselect and gtmktime on our input file list.
# * **bexpmap_00.fits**: All-sky binned exposure map.  This map is interpolated to create an exposure model when generating the srcmap file.
# * **bexpmap_roi_00.fits**: Binned exposure map for the ROI.  This file is only provided for visualization purposes in order to have an exposure map with the same binning as the data and model maps.
# * **ccube_00.fits**: Counts cube for the ROI.
# * **ltcube_00.fits**: Livetime cube.  This contains a map of the livetime for this observation over the whole sky as a function of incidence angle.
# * **srcmap_00.fits**: Source map cube.  This file contains maps for each of the components in the ROI after convolution with exposure and the PSF.  Note that energy dispersion is applied at run-time.
#
# Note that all of the files have a numerical suffix '00'.  This is the analysis component index.  In a multi-component analysis there would be instances of all of the above files for each analysis component.  The files with no component index are co-added maps that are provided for visualization purposes.
#
# To see example of one of these files we can open and plot the counts cube file.  This is a 3D cube that contains the distribution of events as a function of energy and two spatial coordinates.  In the example below we sum over the energy dimension of the cube to make a 2-D sky image.

# %%
import astropy.io.fits as pyfits

h = pyfits.open('data/ccube.fits')
h.info()
counts = h[0].data
counts.shape
plt.figure()
plt.imshow(np.sum(counts,axis=0),interpolation='nearest',origin='lower')
# Out:
# Filename: data/ccube.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU      27   (100, 100, 14)   float32
#   1  EBOUNDS       1 BinTableHDU     22   14R x 4C   [I, E, E, E]

# %% [markdown]
# We can now inspect the state of the ROI prior with the print_roi() method.

# %%
gta.print_roi()
# Out:
# 2021-10-31 16:51:49 INFO    GTAnalysis.print_roi():
# name                SpatialModel   SpectrumType     offset        ts       npred
# --------------------------------------------------------------------------------
# 4FGL J2158.8-3013   PointSource    LogParabola       0.000       nan      1466.9
# 4FGL J2151.8-3027   PointSource    LogParabola       1.527       nan       855.5
# 4FGL J2159.1-2840   PointSource    PowerLaw          1.544       nan        29.6
# 4FGL J2150.7-2810   PointSource    PowerLaw          2.703       nan        64.1
# 4FGL J2145.0-3356   PointSource    LogParabola       4.735       nan       194.1
# 4FGL J2137.4-3209   PointSource    PowerLaw          4.966       nan         8.8
# 4FGL J2142.5-2552   PointSource    PowerLaw          5.638       nan        38.6
# 4FGL J2212.9-2526   PointSource    PowerLaw          5.709       nan        49.3
# 4FGL J2200.7-2414   PointSource    PowerLaw          5.997       nan        11.5
# 4FGL J2227.9-3031   PointSource    PowerLaw          6.275       nan         2.3
# 4FGL J2131.0-2746   PointSource    LogParabola       6.562       nan         3.3
# 4FGL J2221.9-3504   PointSource    PowerLaw          6.867       nan        18.2
# 4FGL J2123.8-3148   PointSource    PowerLaw          7.659       nan         6.6
# 4FGL J2131.7-2515   PointSource    PowerLaw          7.782       nan         2.6
# 4FGL J2141.8-3727   PointSource    PowerLaw          8.043       nan        16.1
# 4FGL J2124.7-3358   PointSource    PLSuperExpCuto    8.133       nan        13.8
# 4FGL J2235.8-3627   PointSource    PowerLaw          9.925       nan         4.7
# isodiff             ConstantValue  FileFunction      -----       nan      4014.2
# galdiff             MapCubeFunctio PowerLaw          -----       nan      4158.4

# %% [markdown]
# Additional details about an individual source can be retrieved by printing the corresponding source object.  Here we use the bracket operator to return the properties of PKS 2155-403.

# %%
print(gta.roi['4FGL J2158.8-3013'])
# Out:
# Name           : 4FGL J2158.8-3013
# Associations   : ['4FGL J2158.8-3013', 'PKS 2155-304', 'J2157-3015', '3EG J2158-3023']
# RA/DEC         :    329.714/   -30.225
# GLON/GLAT      :     17.731/   -52.243
# TS             : nan
# Npred          : 1466.93
# Flux           : 1.166e-07 +/-      nan
# EnergyFlux     : 0.0001558 +/-      nan
# SpatialModel   : PointSource
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :  1.377e-11 +/-        nan
# b'alpha'       :      1.763 +/-        nan
# b'beta'        :    0.04172 +/-        nan
# b'Eb'          :       1136 +/-        nan

# %% [markdown]
# ## Do the likelihood fitting
#
# Now that all of the ancillary files have been generated, we can move on to the actual fitting.  The first thing you should do is free some of the sources since all of the sources are initially fixed.  We'll just free those sources in the center region.

# %%
# Free Normalization of all Sources within 3 deg of ROI center
gta.free_sources(distance=3.0,pars='norm')

# Free all parameters of isotropic and galactic diffuse components
gta.free_source('galdiff')
gta.free_source('isodiff')
# Out:
# 2021-10-31 16:51:58 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J2158.8-3013     : ['norm']
# 2021-10-31 16:51:58 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J2151.8-3027     : ['norm']
# 2021-10-31 16:51:58 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J2159.1-2840     : ['Prefactor']
# 2021-10-31 16:51:58 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J2150.7-2810     : ['Prefactor']
# 2021-10-31 16:51:58 INFO    GTAnalysis.free_source(): Freeing parameters for isodiff               : ['Normalization']
# 2021-10-31 16:51:58 INFO    GTAnalysis.free_source(): Freeing parameters for galdiff               : ['Prefactor']
# 2021-10-31 16:51:58 INFO    GTAnalysis.free_source(): Freeing parameters for galdiff               : ['Index']

# %% [markdown]
# In this simple anlaysis we are leaving the spectral shapes of sources fixed but we're going to free the spectral shape of the source we care about.

# %%
gta.free_source('4FGL J2158.8-3013')
# Out:
# 2021-10-31 16:52:01 INFO    GTAnalysis.free_source(): Freeing parameters for 4FGL J2158.8-3013     : ['alpha', 'beta']

# %% [markdown]
# Now, actually do the fit.  The software does its best to get the fit to converge by running the fit several times.

# %%
fit_results = gta.fit()
# Out:
# 2021-10-31 16:52:04 INFO    GTAnalysis.fit(): Starting fit.
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/scipy/interpolate/fitpack2.py:280: UserWarning:
# The maximal number of iterations maxit (set to 20 by the program)
# allowed for finding a smoothing spline with fp=s has been reached: s
# too small.
# There is an approximation returned but the corresponding weighted sum
# of squared residuals does not satisfy the condition abs(fp-s)/s < tol.
#   warnings.warn(message)
# 2021-10-31 16:52:05 INFO    GTAnalysis.fit(): Fit returned successfully. Quality:   3 Status:   0
# 2021-10-31 16:52:05 INFO    GTAnalysis.fit(): LogLike:   -26086.921 DeltaLogLike:       58.232

# %% [markdown]
# The dictionary returned by the fit method returns a variety of diagnostic information about the fit including the fit quality, the relative improvement in the likelihood, and the correlations among the fit parameters.  We can inspect the results of the fit by printing the source object for PG1553.

# %%
print('Fit Quality: ',fit_results['fit_quality'])
print(gta.roi['4FGL J2158.8-3013'])
# Out:
# Fit Quality:  3
# Name           : 4FGL J2158.8-3013
# Associations   : ['4FGL J2158.8-3013', 'PKS 2155-304', 'J2157-3015', '3EG J2158-3023']
# RA/DEC         :    329.714/   -30.225
# GLON/GLAT      :     17.731/   -52.243
# TS             : 4564.49
# Npred          : 1989.21
# Flux           : 1.611e-07 +/- 9.48e-09
# EnergyFlux     : 0.0002078 +/- 1.82e-05
# SpatialModel   : PointSource
# SpectrumType   : LogParabola
# Spectral Parameters
# b'norm'        :  1.804e-11 +/-  6.952e-13
# b'alpha'       :       1.79 +/-    0.03112
# b'beta'        :    0.03325 +/-    0.01369
# b'Eb'          :       1136 +/-        nan

# %% [markdown]
# You can then save the state of the roi to an output file for reference later.  The write_roi function does this.  The first argument is a string that will be prepended to the names of the output files generated by this method.

# %%
gta.write_roi('fit0',make_plots=True)
# Out:
# 2021-10-31 16:53:05 INFO    GTBinnedAnalysis.write_xml(): Writing /mnt/storage1/users/chen/PHYS3009_fermipy/data/fit0_00.xml...
# 2021-10-31 16:53:05 INFO    GTAnalysis.write_fits(): Writing /mnt/storage1/users/chen/PHYS3009_fermipy/data/fit0.fits...
# WARNING: Format %s cannot be mapped to the accepted TDISPn keyword values.  Format will not be moved into TDISPn keyword. [astropy.io.fits.column]
# WARNING: Format %f cannot be mapped to the accepted TDISPn keyword values.  Format will not be moved into TDISPn keyword. [astropy.io.fits.column]
# 2021-10-31 16:53:30 INFO    GTAnalysis.write_roi(): Writing /mnt/storage1/users/chen/PHYS3009_fermipy/data/fit0.npy...
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/fermipy/plotting.py:146: MatplotlibDeprecationWarning: Passing raw data via parameters data and lut to register_cmap() is deprecated since 3.3 and will become an error two minor releases later. Instead use: register_cmap(cmap=LinearSegmentedColormap(name, data, lut))
#   plt.register_cmap(name='ds9_b', data=ds9_b)
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/fermipy/plotting.py:301: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("magma"))
#   colormap.set_under(colormap(0))
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/astropy/visualization/wcsaxes/core.py:458: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   super().draw(renderer, inframe=inframe)
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/astropy/visualization/wcsaxes/core.py:458: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   super().draw(renderer, inframe=inframe)
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/fermipy/plotting.py:146: MatplotlibDeprecationWarning: Passing raw data via parameters data and lut to register_cmap() is deprecated since 3.3 and will become an error two minor releases later. Instead use: register_cmap(cmap=LinearSegmentedColormap(name, data, lut))
#   plt.register_cmap(name='ds9_b', data=ds9_b)
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/fermipy/plotting.py:301: MatplotlibDeprecationWarning: You are modifying the state of a globally registered colormap. In future versions, you will not be able to modify a registered colormap in-place. To remove this warning, you can make a copy of the colormap first. cmap = copy.copy(mpl.cm.get_cmap("magma"))
#   colormap.set_under(colormap(0))
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/astropy/visualization/wcsaxes/core.py:458: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   super().draw(renderer, inframe=inframe)
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/astropy/visualization/wcsaxes/core.py:458: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   super().draw(renderer, inframe=inframe)
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/astropy/visualization/wcsaxes/core.py:458: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   super().draw(renderer, inframe=inframe)
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/astropy/visualization/wcsaxes/core.py:458: MatplotlibDeprecationWarning:
# The 'inframe' parameter of draw() was deprecated in Matplotlib 3.3 and will be removed two minor releases later. Use Axes.redraw_in_frame() instead. If any parameter follows 'inframe', they should be passed as keyword, not positionally.
#   super().draw(renderer, inframe=inframe)

# %% [markdown]
# There are a lot of diagnostic plots also saved at the same time.

# %%
ls -l data/*.png
# Out:
# -rw-r--r-- 1 chen ldap_users 57935 Oct 31 16:53 data/fit0_counts_map_2.000_5.477.png
# -rw-r--r-- 1 chen ldap_users 22714 Oct 31 16:53 data/fit0_counts_map_xproj_2.000_5.477.png
# -rw-r--r-- 1 chen ldap_users 22867 Oct 31 16:53 data/fit0_counts_map_yproj_2.000_5.477.png
# -rw-r--r-- 1 chen ldap_users 52445 Oct 31 16:53 data/fit0_counts_spectrum.png
# -rw-r--r-- 1 chen ldap_users 49018 Oct 31 16:53 data/fit0_model_map_2.000_5.477.png

# %%
from IPython.display import Image, display
from glob import glob

# %%
pngs = glob('data/*.png')

# %%
for png in pngs:
    my_image = Image(png)
    display(my_image)

# %% [markdown]
# ### Reading in the results
#
# Since the results are saved, you can load them back up at any point (you can also get to these within python).  Here we retrieve the analysis results from the output numpy file.

# %%
c = np.load('data/fit0.npy', allow_pickle=True).flat[0]

# %% [markdown]
# The `sources` dictionary has an entry for each source in the model:

# %%
sorted(c['sources'].keys())
# Out:
# ['4FGL J2123.8-3148',
#  '4FGL J2124.7-3358',
#  '4FGL J2131.0-2746',
#  '4FGL J2131.7-2515',
#  '4FGL J2137.4-3209',
#  '4FGL J2141.8-3727',
#  '4FGL J2142.5-2552',
#  '4FGL J2145.0-3356',
#  '4FGL J2150.7-2810',
#  '4FGL J2151.8-3027',
#  '4FGL J2158.8-3013',
#  '4FGL J2159.1-2840',
#  '4FGL J2200.7-2414',
#  '4FGL J2212.9-2526',
#  '4FGL J2221.9-3504',
#  '4FGL J2227.9-3031',
#  '4FGL J2235.8-3627',
#  'galdiff',
#  'isodiff']

# %% [markdown]
# Let's take a look at the flux, spectral parameters, and TS.

# %%
c['sources']['4FGL J2158.8-3013']['flux']
# Out:
# 1.6107933059901753e-07

# %%
print(c['sources']['4FGL J2158.8-3013']['param_names'][:4])
print(c['sources']['4FGL J2158.8-3013']['param_values'][:4])
# Out:
# [b'norm' b'alpha' b'beta' b'Eb']
# [1.80353016e-11 1.78999079e+00 3.32548552e-02 1.13648315e+03]

# %%
c['sources']['4FGL J2158.8-3013']['ts']
# Out:
# 4564.491294800049

# %% [markdown]
# The SED is in there as well.  We can plot it.

# %%
E = np.array(c['sources']['4FGL J2158.8-3013']['model_flux']['energies'])
dnde = np.array(c['sources']['4FGL J2158.8-3013']['model_flux']['dnde'])
dnde_hi = np.array(c['sources']['4FGL J2158.8-3013']['model_flux']['dnde_hi'])
dnde_lo = np.array(c['sources']['4FGL J2158.8-3013']['model_flux']['dnde_lo'])

# %%
plt.loglog(E, (E**2)*dnde, 'k--')
plt.loglog(E, (E**2)*dnde_hi, 'k')
plt.loglog(E, (E**2)*dnde_lo, 'k')
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^2$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')
plt.show()

# %% [markdown]
# If you want SED points, there's a function for that.  There are lots of options for this which you can set in the config file or from keyword arguments of the function itself.

# %%
sed = gta.sed('4FGL J2158.8-3013',make_plots=True)
# Out:
# 2021-10-31 16:54:35 INFO    GTAnalysis.sed(): Computing SED for 4FGL J2158.8-3013
# 2021-10-31 16:54:35 INFO    GTAnalysis._make_sed(): Fitting SED
# 2021-10-31 16:54:35 INFO    GTAnalysis.free_source(): Fixing parameters for 4FGL J2158.8-3013     : ['alpha', 'beta']
# 2021-10-31 16:54:35 INFO    GTAnalysis.free_source(): Fixing parameters for galdiff               : ['Index']
# 2021-10-31 16:54:37 INFO    GTAnalysis.sed(): Finished SED
# /HddData/software/Anaconda3-2020.07/envs/fermipy/lib/python3.7/site-packages/fermipy/plotting.py:719: MatplotlibDeprecationWarning: shading='flat' when X and Y have the same dimensions as C is deprecated since 3.3.  Either specify the corners of the quadrilaterals with X and Y, or pass shading='auto', 'nearest' or 'gouraud', or set rcParams['pcolor.shading'].  This will become an error two minor releases later.
#   linewidth=0)
# 2021-10-31 16:54:55 INFO    GTAnalysis.sed(): Execution time: 19.92 s

# %% [markdown]
# You can save the state to the yaml file or you can just access it directly.  This is also the way to get at the dictionary for any individual source.

# %%
src = gta.roi['4FGL J2158.8-3013']

# %%
plt.loglog(E, (E**2)*dnde, 'k--')
plt.loglog(E, (E**2)*dnde_hi, 'k')
plt.loglog(E, (E**2)*dnde_lo, 'k')
plt.errorbar(np.array(sed['e_ctr']),
             sed['e2dnde'], 
             yerr=sed['e2dnde_err'], fmt ='o')
plt.xlabel('E [MeV]')
plt.ylabel(r'E$^{2}$ dN/dE [MeV cm$^{-2}$ s$^{-1}$]')
plt.show()

# %%
from astropy.table import Table
sed_tab = Table.read('data/4fgl_j2158.8-3013_sed.fits')
sed_tab.write('data/4fgl_j2158.8-3013_sed.ecsv',exclude_names=['norm_scan','dloglike_scan'])
# Out:
# WARNING: hdu= was not specified but multiple tables are present, reading in first available table (hdu=1) [astropy.io.fits.connect]

# %% [markdown]
# ### Summary
#
# There is a lot of other functionality and you should look through the docs for more details.  You can also inspect the GTAnalysis object for some of these (like TS Maps, extension tests, and using event types).  Following threads cover some of the more advanced functionality of fermipy:
#
# * [IC443](ic443.ipynb) : Analysis to measure the angular extension of the SNR IC443.
# * [Draco](draco.ipynb) : DM upper limit analysis of the Draco dwarf spheroidal galaxy.
